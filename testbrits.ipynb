# %%
# !git clone https://github.com/dmlc/dgl.git

# %%
# !pip install dgl dglgo -f https://data.dgl.ai/wheels/repo.html
# !pip install ogb

# %%
# !cd dgl/examples/pytorch/graphsage/dist/ && echo "y" > sure  && python3 partition_graph.py --dataset ogb-product --num_parts 1 < sure

# %%
# !cd dgl/examples/pytorch/graphsage/dist/ && python3 train_dist_unsupervised.py --graph_name ogb-product --ip_config ip_config.txt --num_epochs 3 --batch_size 1000 --part_config data/ogb-product.json --standalone
